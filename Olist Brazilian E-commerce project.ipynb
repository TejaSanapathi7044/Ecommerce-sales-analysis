# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import files
df=files.upload()
# Out:
#      <input type="file" id="files-ae86e902-77d0-4dca-aa47-6c3cad42602d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ae86e902-77d0-4dca-aa47-6c3cad42602d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df.keys()
# Out:
# dict_keys(['archive (7).zip'])

# %%
import zipfile

with zipfile.ZipFile('archive (7).zip', 'r') as zip_ref:
    zip_ref.extractall('/content/')

# %%
import os
os.listdir()
# Out:
# ['.config',
#  'olist_sellers_dataset.csv',
#  'olist_order_items_dataset.csv',
#  'olist_geolocation_dataset.csv',
#  'olist_customers_dataset.csv',
#  'olist_products_dataset.csv',
#  'olist_order_reviews_dataset.csv',
#  'archive (7).zip',
#  'product_category_name_translation.csv',
#  'olist_order_payments_dataset.csv',
#  'olist_orders_dataset.csv',
#  'sample_data']

# %%
customers=pd.read_csv('olist_customers_dataset.csv')
geolocation=pd.read_csv('olist_geolocation_dataset.csv')
orders=pd.read_csv('olist_orders_dataset.csv')
order_items=pd.read_csv('olist_order_items_dataset.csv')
orders_reviews=pd.read_csv('olist_order_reviews_dataset.csv')
orders_payments=pd.read_csv('olist_order_payments_dataset.csv')
products=pd.read_csv('olist_products_dataset.csv')
sellers=pd.read_csv('olist_sellers_dataset.csv')
product_category=pd.read_csv('product_category_name_translation.csv')

# %%
customers.shape
orders.shape
order_items.shape
# Out:
# (112650, 7)

# %%
orders.columns
# Out:
# Index(['order_id', 'customer_id', 'order_status', 'order_purchase_timestamp',
#        'order_approved_at', 'order_delivered_carrier_date',
#        'order_delivered_customer_date', 'order_estimated_delivery_date'],
#       dtype='object')

# %%
orders['order_purchase_timestamp'] = pd.to_datetime(orders['order_purchase_timestamp'])
orders['order_delivered_customer_date'] = pd.to_datetime(orders['order_delivered_customer_date'])
orders['order_estimated_delivery_date'] = pd.to_datetime(orders['order_estimated_delivery_date'])

# %%
orders
# Out:
#                                order_id                       customer_id  \
# 0      e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1      53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 2      47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# 3      949d5b44dbf5de918fe9c16f97b45f8a  f88197465ea7920adcdbec7375364d82
# 4      ad21c59c0840e6cb83a9ceb5573f8159  8ab97904e6daea8866dbdbc4fb7aad2c
# ...                                 ...                               ...
# 99436  9c5dedf39a927c1b2549525ed64a053c  39bd1228ee8140590ac3aca26f2dfe00
# 99437  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 99438  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 99439  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 99440  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#       order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
orders["delivery_time"]=orders["order_delivered_customer_date"]-orders["order_purchase_timestamp"]
orders["delay"]=orders["order_delivered_customer_date"]-orders["order_estimated_delivery_date"]
orders["delayed"]=orders["delay"].apply(lambda x: 1 if x.total_seconds() > 0 else 0)

# %%
orders[orders["delayed"]==1]
# Out:
#                                order_id                       customer_id  \
# 20     203096f03d82e0dffbc41ebc2e2bcfb7  d2b091571da224a1b36412c18bc3bbfe
# 25     fbf9ac61453ac646ce8ad9783d7d0af6  3a874b4d4c4b6543206ff5d89287f0c3
# 35     8563039e855156e48fccee4d611a3196  5f16605299d698660e0606f7eae2d2f9
# 41     6ea2f835b4556291ffdc53fa0b3b95e8  c7340080e394356141681bd4c9b8fe31
# 57     66e4624ae69e7dc89bd50222b59f581f  684fa6da5134b9e4dab731e00011712d
# ...                                 ...                               ...
# 99396  b3112ca67f3afd4e20cf2ee91fc4f804  6f83c71b6c044fb156d697d4130fe9b5
# 99397  0fa1fab1d7c1211c824596ed5e111e3c  7f3bd6c94d2daf7b6462d1a894a775b4
# 99423  38e9133ce29f6bbe35aed9c3863dce01  ad312389a098ceff46ce92c4595c06d0
# 99425  d692ef54145c9cb3322ec2e5508aa3f4  82ddfcf9438b0cd1117b55ac33184df8
# 99432  cfa78b997e329a5295b4ee6972c02979  a2f7428f0cafbc8e59f20e1444b67315
#
#       order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
order_value=order_items.groupby("order_id")["price"].sum().reset_index()
order_value.rename(columns={"price":"total_order_value"},inplace=True)

# %%
order_value
# Out:
#                                order_id  total_order_value
# 0      00010242fe8c5a6d1ba2dd792cb16214              58.90
# 1      00018f77f2f0320c557190d7a144bdd3             239.90
# 2      000229ec398224ef6ca0657da4fc703e             199.00
# 3      00024acbcdf0a6daa1e931b038114c75              12.99
# 4      00042b26cf59d7ce69dfabb4e55b4fd9             199.90
# ...                                 ...                ...
# 98661  fffc94f6ce00a00581880bf54a75a037             299.99
# 98662  fffcd46ef2263f404302a634eb57f7eb             350.00
# 98663  fffce4705a9662cd70adb13d4a31832d              99.90
# 98664  fffe18544ffabc95dfada21779c9644f              55.99
# 98665  fffe41c64501cc87c801fd61db3f6244              43.00
#
# [98666 rows x 2 columns]

# %%
df = orders.merge(customers, on='customer_id', how='left')

df = df.merge(order_items, on='order_id', how='left')

df = df.merge(order_value, on='order_id', how='left')

df = df.merge(orders_payments, on='order_id', how='left')

df = df.merge(orders_reviews, on='order_id', how='left')

df = df.merge(products, on='product_id', how='left')

# %%
df["order_month"]=df["order_purchase_timestamp"].dt.to_period("M")
df["order_day"]=df["order_purchase_timestamp"].dt.day_name()
df["is_weekend"]=df["order_day"].isin(["Saturday","Sunday"]).astype(int)

# %%
df
# Out:
#                                 order_id                       customer_id  \
# 0       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 1       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 2       e481f51cbdc54678b7cc49136f2d6af7  9ef432eb6251297304e76186b10a928d
# 3       53cdb2fc8bc7dce0b6741e2150273451  b0830fb4747a6c6d20dea0b8c802d7ef
# 4       47770eb9100c2d0c44946d9cf07ec65d  41ce2a54c0b03bf3443c3d931a367089
# ...                                  ...                               ...
# 119138  63943bddc261676b46f01ca7ac2f7bd8  1fca14ff2861355f6e5f14306ff977a7
# 119139  83c1379a015df1e13d02aae0204711ab  1aa71eb042121263aafbe80c1b562c9c
# 119140  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 119141  11c177c8e97725db2631073c19f07b62  b331b74b18dc79bcdf6532d51e1637c1
# 119142  66dea50a8b16d9b4dee7af250b4be1a5  edb027a75a1449115f6b43211ae02a24
#
#        order_status order_purchase_timestamp    order_approved_at  \
# ...

# %%
df.columns
# Out:
# Index(['order_id', 'customer_id', 'order_status', 'order_purchase_timestamp',
#        'order_approved_at', 'order_delivered_carrier_date',
#        'order_delivered_customer_date', 'order_estimated_delivery_date',
#        'delivery_time', 'delay', 'delayed', 'customer_unique_id',
#        'customer_zip_code_prefix', 'customer_city', 'customer_state',
#        'order_item_id', 'product_id', 'seller_id', 'shipping_limit_date',
#        'price', 'freight_value', 'total_order_value', 'payment_sequential',
#        'payment_type', 'payment_installments', 'payment_value', 'review_id',
#        'review_score', 'review_comment_title', 'review_comment_message',
#        'review_creation_date', 'review_answer_timestamp',
#        'product_category_name', 'product_name_lenght',
#        'product_description_lenght', 'product_photos_qty', 'product_weight_g',
#        'product_length_cm', 'product_height_cm', 'product_width_cm',
#        'order_month', 'order_day', 'is_weekend'],
# ...

# %%
delayed_orders = df[df["delayed"] == 1][["order_id","total_order_value"]]

# %%
len(df[df["delayed"]==1])
# Out:
# 9068

# %%
df.shape
# Out:
# (119143, 43)

# %%
columns_to_drop = [
    'customer_unique_id','order_item_id','product_id','seller_id','review_id',
    'review_comment_title','review_comment_message',
    'product_description_lenght',
    'product_weight_g','product_length_cm','product_height_cm','product_width_cm',
    'price','freight_value','payment_sequential','payment_installments',
    'order_approved_at','order_delivered_carrier_date','shipping_limit_date',
    'review_creation_date','review_answer_timestamp'
]

df = df.drop(columns=columns_to_drop)

# %%
df.shape
# Out:
# (119143, 22)

# %%
df.isnull().sum()
# Out:
# order_id                            0
# customer_id                         0
# order_status                        0
# order_purchase_timestamp            0
# order_delivered_customer_date    3421
# order_estimated_delivery_date       0
# delivery_time                    3421
# delay                            3421
# delayed                             0
# customer_zip_code_prefix            0
# customer_city                       0
# customer_state                      0
# total_order_value                 833
# payment_type                        3
# payment_value                       3
# review_score                      997
# product_category_name            2542
# product_name_lenght              2542
# product_photos_qty               2542
# order_month                         0
# order_day                           0
# is_weekend                          0
# dtype: int64

# %%
df=df[df["order_delivered_customer_date"].notna()]

# %%
df = df[df["total_order_value"].notna()]

# %%
df["review_score"].fillna(0,inplace=True)
# Out:
# /tmp/ipykernel_6191/333981979.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["review_score"].fillna(0,inplace=True)

# %%
df["product_category_name"].fillna('Unknown', inplace=True)
# Out:
# /tmp/ipykernel_6191/1425065534.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["product_category_name"].fillna('Unknown', inplace=True)

# %%
df = df.drop(columns=["product_name_lenght","product_photos_qty"])

# %%
df.isnull().sum()
# Out:
# order_id                         0
# customer_id                      0
# order_status                     0
# order_purchase_timestamp         0
# order_delivered_customer_date    0
# order_estimated_delivery_date    0
# delivery_time                    0
# delay                            0
# delayed                          0
# customer_zip_code_prefix         0
# customer_city                    0
# customer_state                   0
# total_order_value                0
# payment_type                     3
# payment_value                    3
# review_score                     0
# product_category_name            0
# order_month                      0
# order_day                        0
# is_weekend                       0
# dtype: int64

# %%
df.shape
# Out:
# (115722, 20)

# %%
from google.colab import files
df.to_csv("Olist Brazilian E-commerce Dataset.csv", index=False)
files.download("Olist Brazilian E-commerce Dataset.csv")
